# %%
import sys
import os
import pandas as pd
sys.path.append(os.path.abspath('../Script'))

# %%
import labeling as la

# %%
df = pd.read_csv('clean_data.csv')

# %%
df
# Out:
#       Unnamed: 0   Channel Title   ZemenExpress    ID  \
# 0              8  Zemen Express®  @ZemenExpress  5337
# 1             10  Zemen Express®  @ZemenExpress  5335
# 2             11  Zemen Express®  @ZemenExpress  5334
# 3             12  Zemen Express®  @ZemenExpress  5333
# 4             13  Zemen Express®  @ZemenExpress  5332
# ...          ...             ...            ...   ...
# 2140        5003  Zemen Express®  @ZemenExpress   125
# 2141        5004  Zemen Express®  @ZemenExpress   123
# 2142        5007  Zemen Express®  @ZemenExpress   115
# 2143        5008  Zemen Express®  @ZemenExpress   114
# 2144        5009  Zemen Express®  @ZemenExpress   113
#
#                                                 Message  \
# 0     ['Baby', 'Feeding', 'Bottle', 'Spoon', 'with',...
# 1     ['ለመላው', 'የክርስትና', 'እምነት', 'ተከታዮች', 'በሙሉ', 'እን...
# 2     ['Korean', 'Body', 'Scrub', 'Sponge', 'የሞተ', '...
# 3     ['Korean', 'Body', 'Scrub', 'Sponge', 'የሞተ', '...
# ...

# %%
 "['Folding', 'Egg', 'Rack', 'ከፍተኛ', 'ጥራት', 'እስከ', '30', 'እንቁላል', 'መያዝ', 'የሚችል', 'ፍሪጅዎን', 'በስርአት', 'ለመጠቀም', 'ተመራጭ', 'ለመኖሪያ', 'ቤት', 'እንዲሁም', 'ለሬስቶራንት', 'የሚሆን', '24', 'egg', 'storage', 'holder', '3', 'layer', 'foldable', 'egg', 'organizer', 'kitchen', 'countertop', 'portable', 'egg', 'carrier', 'ዋጋ', '1', '100', 'ብር', 'ውስን', 'ፍሬ', 'ያለው', 'አድራሻ', 'ቁ', '1', 'መገናኛ', 'መሰረት', 'ደፋር', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ', 'S05', 'S06', 'ቁ', '2', 'ፒያሳ', 'ጊዮርጊስ', 'አደባባይ', 'ራመት_ታቦር_ኦዳ_ህንፃ', '1ኛ', 'ፎቅ', 'ሱቅ', 'ቁ', 'G1', '107', '0902660722', '0928460606', 'ፒያሳ', 'ቅርንጫፍ', '0941337070', 'በTelegram', 'ለማዘዝ', 'ይጠቀሙ', 'zemencallcenter', 'zemenexpressadmin', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን', 'https', 'telegram', 'me', 'zemenexpress']",
 "['የሸቶ', 'መቀነሻ', 'Mini', 'spray', 'pour', 'የሸቶ', 'መቀነሻ', 'ዋጋ', '200', 'ብር', 'ውስን', 'ፍሬ', 'ያለው', 'አድራሻ', 'ቁ', '1', 'መገናኛ', 'መሰረት', 'ደፋር', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ', 'S05', 'S06', 'ቁ', '2', 'ፒያሳ', 'ጊዮርጊስ', 'አደባባይ', 'ራመት_ታቦር_ኦዳ_ህንፃ', '1ኛ', 'ፎቅ', 'ሱቅ', 'ቁ', 'G1', '107', '0902660722', '0928460606', 'ፒያሳ', 'ቅርንጫፍ', '0941337070', 'በTelegram', 'ለማዘዝ', 'ይጠቀሙ', 'zemencallcenter', 'zemenexpressadmin', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን', 'https', 'telegram', 'me', 'zemenexpress']",
 "['Multi', 'purpose', 'Glass', 'Bowl', 'ባለብዙ', 'ጥቅም', 'የመስታወት', 'ጎድጓዳ', 'ሳህኖች', 'ከ', 'ብርጭቆ', 'የተሰራ', 'ለቤተዎ', 'ተጨማሪ', 'ውበትን', 'የሚሰጥ', 'ለሳላድ', 'እንዲሁም', 'ለዎጥ', 'ማቅረቢያ', 'ተመራጭ', 'ዋጋ', '450', 'ብር', 'ውስን', 'ፍሬ', 'ያለው', 'አድራሻ', 'ቁ', '1', 'መገናኛ', 'መሰረት', 'ደፋር', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ', 'S05', 'S06', 'ቁ', '2', 'ፒያሳ', 'ጊዮርጊስ', 'አደባባይ', 'ራመት_ታቦር_ኦዳ_ህንፃ', '1ኛ', 'ፎቅ', 'ሱቅ', 'ቁ', 'G1', '107', '0902660722', '0928460606', 'ፒያሳ', 'ቅርንጫፍ', '0941337070', 'በTelegram', 'ለማዘዝ', 'ይጠቀሙ', 'zemencallcenter', 'zemenexpressadmin', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን', 'https', 'telegram', 'me', 'zemenexpress']",
 "['Creative', '6', 'layer', 'Shoe', 'Rack', 'የጫማ', 'ማስቀመጫ', 'ባለ', 'ስድስት', 'ደረጃ', 'ቦታ', 'ቆጣቢ', 'ሲዘረጋ', '27cm', '27cm', '86cm', 'ስፋት', 'ከጠንካራ', 'ፕላስቲክ', 'የተሰራ', 'ገጠማ', 'የማይፈልግ', '6', 'ጥንድ', 'ጫማዎችን', 'ይይዛል', 'ዋጋ', '1950ብር', 'ውስን', 'ፍሬ', 'ያለው', 'አድራሻ', 'ቁ', '1', 'መገናኛ', 'መሰረት', 'ደፋር', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ', 'S05', 'S06', 'ቁ', '2', 'ፒያሳ', 'ጊዮርጊስ', 'አደባባይ', 'ራመት_ታቦር_ኦዳ_ህንፃ', '1ኛ', 'ፎቅ', 'ሱቅ', 'ቁ', 'G1', '107', '0902660722', '0928460606', 'ፒያሳ', 'ቅርንጫፍ', '0941337070', 'በTelegram', 'ለማዘዝ', 'ይጠቀሙ', 'zemencallcenter', 'zemenexpressadmin', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን', 'https', 'telegram', 'me', 'zemenexpress']",
 "['ሴራሚክ', 'ንግስተ', 'ሳባ', 'መመገቢያ', 'ሳህን', 'ከፍተኛ', 'ጥራት', 'ያለው', 'ዋጋ', '6ፍሬ', '1ኛ', 'ደረጃ', '4000', 'ብር', 'አድራሻ', 'ቁ', '1', 'መገናኛ', 'መሰረት', 'ደፋር', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ', 'S05', 'S06', 'ቁ', '2', 'ፒያሳ', 'ጊዮርጊስ', 'አደባባይ', 'ራመት_ታቦር_ኦዳ_ህንፃ', '1ኛ', 'ፎቅ', 'ሱቅ', 'ቁ', 'G1', '107', '0902660722', '0928460606', 'ፒያሳ', 'ቅርንጫፍ', '0941337070', 'በTelegram', 'ለማዘዝ', 'ይጠቀሙ', 'zemencallcenter', 'zemenexpressadmin', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን', 'https', 'telegram', 'me', 'zemenexpress']",
 "['ቅናሽ', 'Magic', 'Silicone', 'Dish', 'Washing', 'Gloves', 'High', 'Quality', 'ወፍራሙ', 'ዕቃ', 'ለማጠብ', 'ቤት', 'ለማፅዳት', 'መኪና', 'ለማጠብ', 'ለተለያየ', 'አገልግሎት', 'የሚውል', 'ዋጋ', '350', 'ብር', 'ውስን', 'ፍሬ', 'ያለው', 'አድራሻ', 'ቁ', '1', 'መገናኛ', 'መሰረት', 'ደፋር', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ', 'S05', 'S06', 'ቁ', '2', 'ፒያሳ', 'ጊዮርጊስ', 'አደባባይ', 'ራመት_ታቦር_ኦዳ_ህንፃ', '1ኛ', 'ፎቅ', 'ሱቅ', 'ቁ', 'G1', '107', '0902660722', '0928460606', 'ፒያሳ', 'ቅርንጫፍ', '0941337070', 'በTelegram', 'ለማዘዝ', 'ይጠቀሙ', 'zemencallcenter', 'zemenexpressadmin', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን', 'https', 'telegram', 'me', 'zemenexpress']",
 "['Lunch', 'Box', 'ባለ', 'ሁለት', 'ምሳቃ', 'ከማያቀዘቅዝ', 'ማቴሪያል', 'የተሰራ', 'በተጨማሪም', 'የራሱ', 'የማያቀዘቅዝ', 'መያዣ', 'ያለው', 'ዋጋ', '1700', 'ብር', 'ውስን', 'ፍሬ', 'ያለው', 'አድራሻ', 'ቁ', '1', 'መገናኛ', 'መሰረት', 'ደፋር', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ', 'S05', 'S06', 'ቁ', '2', 'ፒያሳ', 'ጊዮርጊስ', 'አደባባይ', 'ራመት_ታቦር_ኦዳ_ህንፃ', '1ኛ', 'ፎቅ', 'ሱቅ', 'ቁ', 'G1',
 'አድራሻ', 'ቁ', '1', 'መገናኛ', 'መሰረት', 'ደፋር', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ', 'S05', 'S06', 'ቁ', '2', 'ፒያሳ', 'ጊዮርጊስ', 'አደባባይ', 'ራመት_ታቦር_ኦዳ_ህንፃ', '1ኛ', 'ፎቅ', 'ሱቅ', 'ቁ', 'G1', '107', '0902660722', '0928460606', 'ፒያሳ', 'ቅርንጫፍ', '0941337070', 'በTelegram', 'ለማዘዝ', 'ይጠቀሙ', 'zemencallcenter', 'zemenexpressadmin', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን', 'https', 'telegram', 'me', 'zemenexpress']",
 "['የልብስ', 'ማስጫ', 'ማድረቂያ', 'Three', 'Layers', 'of', 'clothes', 'hanger', '3double', 'layer', '780', '620', '1650', 'mm', 'እስከ', '30kg', 'መሸከም', 'ሚችል', 'ማጠፍ', 'መዘርጋት', 'ሚቻል', 'ቦታ', 'ቆጣቢ', 'ለcondominuinm', 'ልብስን', 'ሳይገረጣ', 'በፍጥነት', 'የሚያደርቅ', 'በቤት', 'ውስጥም', 'ሆነ', 'ከቤት', 'ውጭ', 'ልብሶችን', 'ለማድረቅ', 'ለመስቀል', 'ተስማሚ', 'የሆነ', 'ዋጋ', '3400', 'ብር', 'አድራሻ', 'ቁ', '1', 'መገናኛ', 'መሰረት', 'ደፋር', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ', 'S05', 'S06', 'ቁ', '2', 'ፒያሳ', 'ጊዮርጊስ', 'አደባባይ', 'ራመት_ታቦር_ኦዳ_ህንፃ', '1ኛ', 'ፎቅ', 'ሱቅ', 'ቁ', 'G1', '107', '0902660722', '0928460606', 'ፒያሳ', 'ቅርንጫፍ', '0941337070', 'በTelegram', 'ለማዘዝ', 'ይጠቀሙ', 'zemencallcenter', 'zemenexpressadmin', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን', 'https', 'telegram', 'me', 'zemenexpress']",
 "['የልብስ', 'ማስጫ', 'ማድረቂያ', 'Three', 'Layers', 'of', 'clothes', 'hanger', '3double', 'layer', '780', '620', '1650', 'mm', 'እስከ', '40kg', 'መሸከም', 'ሚችል', 'ማጠፍ', 'መዘርጋት', 'ሚቻል', 'ቦታ', 'ቆጣቢ', 'ለcondominuinm', 'ልብስን', 'በፍጥነት', 'የሚያደርቅ', 'በቤት', 'ውስጥም', 'ሆነ', 'ከቤት', 'ውጭ', 'ልብሶችን', 'ለማድረቅ', 'ለመስቀል', 'ተስማሚ', 'የሆነ', 'ዋጋ', '3400', 'ብር', 'አድራሻ', 'ቁ', '1', 'መገናኛ', 'መሰረት', 'ደፋር', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ', 'S05', 'S06', 'ቁ', '2', 'ፒያሳ', 'ጊዮርጊስ', 'አደባባይ', 'ራመት_ታቦር_ኦዳ_ህንፃ', '1ኛ', 'ፎቅ', 'ሱቅ', 'ቁ', 'G1', '107', '0902660722', '0928460606', 'ፒያሳ', 'ቅርንጫፍ', '0941337070', 'በTelegram', 'ለማዘዝ', 'ይጠቀሙ', 'zemencallcenter', 'zemenexpressadmin', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን', 'https', 'telegram', 'me', 'zemenexpress']",
 "['Replacement', 'Silicon', 'Nipple', 'የጡት', 'ጫፍ', 'ዋጋ', '400', 'ብር', 'አድራሻ', 'ቁ', '1', 'መገናኛ', 'መሰረት', 'ደፋር', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ', 'S05', 'S06', 'ቁ', '2', 'ፒያሳ', 'ጊዮርጊስ', 'አደባባይ', 'ራመት_ታቦር_ኦዳ_ህንፃ', '1ኛ', 'ፎቅ', 'ሱቅ', 'ቁ', 'G1', '107', '0902660722', '0928460606', 'ፒያሳ', 'ቅርንጫፍ', '0941337070', 'በTelegram', 'ለማዘዝ', 'ይጠቀሙ', 'zemencallcenter', 'zemenexpressadmin', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን', 'https', 'telegram', 'me', 'zemenexpress']",
 "['የቡና', 'ረከቦት', 'ትልቁ', 'መጠን', 'በአልኮል', 'በሻማ', 'ቡና', 'ማሞቂያ', 'ያለው', 'የጀበና', 'ማስቀመጫ', 'የስኳር', 'ማቅረቢያ', 'የከሰል', 'እጣን', 'ማጨሻ', 'ባለ', 'ሁለት', 'ደረጃ', 'ረከቦት', 'ዋጋ', '16', '500', 'ብር', 'ውስን', 'ፍሬ', 'ያለው', 'አድራሻ', 'ቁ', '1', 'መገናኛ', 'መሰረት', 'ደፋር', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ', 'S05', 'S06', 'ቁ', '2', 'ፒያሳ', 'ጊዮርጊስ', 'አደባባይ', 'ራመት_ታቦር_ኦዳ_ህንፃ', '1ኛ', 'ፎቅ', 'ሱቅ', 'ቁ', 'G1', '107', '0902660722', '0928460606', 'ፒያሳ', 'ቅርንጫፍ', '0941337070', 'በTelegram', 'ለማዘዝ', 'ይጠቀሙ', 'zemencallcenter', 'zemenexpressadmin', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን', 'https', 'telegram', 'me', 'zemenexpress']",
 "['ተጣጣፊ', 'ፑሽ', 'አፕ', 'መሳሪያ', 'Foldable', 'Push', 'Up', 'Board', 'Training', 'Chest', 'ለደረት', 'Triceps', 'ለላይኛዉ', 'ክንድ', 'ጡንቻ', 'Back', 'ለኃላ', 'እጅ', 'Shoulders', 'ለትከሻ', 'ዋጋ', '1400', 'ብር', 'ውስን', 'ፍሬ', 'ያለው', 'አድራሻ', 'ቁ', '1', 'መገናኛ', 'መሰረት', 'ደፋር', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ', 'S05', 'S06', 'ቁ', '2', 'ፒያሳ', 'ጊዮርጊስ', 'አደባባይ', 'ራመት_ታቦር_ኦዳ_ህንፃ', '1ኛ', 'ፎቅ', 'ሱቅ', 'ቁ', 'G1', '107', '0902660722', '0928460606', 'ፒያሳ', 'ቅርንጫፍ', '0941337070', 'በTelegram', 'ለማዘዝ', 'ይጠቀሙ', 'zemencallcenter', 'zemenexpressadmin', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን', 'https', 'telegram', 'me', 'zemenexpress']",
 "['የእንቁላል', 'ሊጥ', 'መምቻ', 'ለአጠቃቀም', 'በጣም', 'ምቹ', 'ፍጥነት', 'መቆጣጠሪያ', 'ያለው', 'ለሊጥ', 'እንቁላል', 'መምቻ', 'የሚሆን', 'ክሬም', 'መስርያ', 'የተፈጨ', 'ስጋ', 'ለማደባለቅ', 'የራሱ', 'መለዋወጫ', 'ያለው', '260w', 'ዋጋ', '1300ብር', 'ውስን', 'ፍሬ', 'ያለው', 'ቁ', '1', 'መገናኛ', 'መሰረት', 'ደፋር', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ', 'S05', 'S06', 'ቁ', '2', 'ፒያሳ', 'ጊዮርጊስ', 'አደባባይ', 'ራመት_ታቦር_ኦዳ_ህንፃ', '1ኛ', 'ፎቅ', 'ሱቅ', 'ቁ', 'G1', '107', '0902660722', '0928460606', 'ፒያሳ', 'ቅርንጫፍ', '0941337070', 'በTelegram', 'ለማዘዝ', 'ይጠቀሙ', 'zemencallcenter', 'zemenexpressadmin', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን', 'https', 'telegram', 'me', 'zemenexpress']",
# Out:
# ("['የእንቁላል', 'ሊጥ', 'መምቻ', 'ለአጠቃቀም', 'በጣም', 'ምቹ', 'ፍጥነት', 'መቆጣጠሪያ', 'ያለው', 'ለሊጥ', 'እንቁላል', 'መምቻ', 'የሚሆን', 'ክሬም', 'መስርያ', 'የተፈጨ', 'ስጋ', 'ለማደባለቅ', 'የራሱ', 'መለዋወጫ', 'ያለው', '260w', 'ዋጋ', '1300ብር', 'ውስን', 'ፍሬ', 'ያለው', 'ቁ', '1', 'መገናኛ', 'መሰረት', 'ደፋር', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ', 'S05', 'S06', 'ቁ', '2', 'ፒያሳ', 'ጊዮርጊስ', 'አደባባይ', 'ራመት_ታቦር_ኦዳ_ህንፃ', '1ኛ', 'ፎቅ', 'ሱቅ', 'ቁ', 'G1', '107', '0902660722', '0928460606', 'ፒያሳ', 'ቅርንጫፍ', '0941337070', 'በTelegram', 'ለማዘዝ', 'ይጠቀሙ', 'zemencallcenter', 'zemenexpressadmin', 'ለተጨማሪ', 'ማብራሪያ', 'የቴሌግራም', 'ገፃችን', 'https', 'telegram', 'me', 'zemenexpress']",)

# %%
import re

# %%
import re

# Function to label tokens with B-Product, I-Product, B-LOC, I-LOC, B-PRICE, and I-PRICE
def label_tokens_with_price(tokens):
    labeled_tokens = []
    
    # Label the first token as B-Product
    if tokens:
        labeled_tokens.append(f"{tokens[0]} B-Product")
    
    # Label the next three tokens as I-Product (if they exist)
    for token in tokens[1:4]:
        labeled_tokens.append(f"{token} I-Product")
    
    # Label specific tokens for B-LOC and I-LOC
    for token in tokens[4:]:
        if token == "መገናኛ" or token == "ፒያሳ":
            labeled_tokens.append(f"{token} B-LOC")
        elif token in ["ራመት_ታቦር_ኦዳ_ህንፃ", "ጊዮርጊስ", "አደባባይ", "መሰረት", "ደፋር", "ሞል"]:
            labeled_tokens.append(f"{token} I-LOC")
        elif token == "ዋጋ":
            labeled_tokens.append(f"{token} B-PRICE")
        elif token == "ብር":
            labeled_tokens.append(f"{token} I-PRICE")  # Assuming "ብር" follows "ዋጋ"
        elif re.match(r'^\d{3,}$', token):  # Label 3-digit numbers and above as I-PRICE
            labeled_tokens.append(f"{token} I-PRICE")
        else:
            labeled_tokens.append(f"{token} O")
    
    return labeled_tokens

# Function to process and label a subset of 200 messages from the data
def process_and_label_200_messages_with_price(df, num_messages=200):
    labeled_data = []
    
    # Take the first 200 messages
    for i, message in enumerate(df['Message'][:num_messages]):
        tokens = re.findall(r'\w+', message)  # Tokenizing the message
        labeled_tokens = label_tokens_with_price(tokens)  # Labeling the tokens
        
        # Append each message's labeled tokens
        labeled_data.append("\n".join(labeled_tokens))
    
    # Join labeled messages with blank lines between them
    return "\n\n".join(labeled_data)

# Apply the function to label the first 200 messages
labeled_data = process_and_label_200_messages_with_price(df, num_messages=200)

# Save to a text file in the correct path
output_path = 'labeled_200_messages_with_price.conll'
with open(output_path, 'w', encoding='utf-8') as f:
    f.write(labeled_data)

print(f"Data has been labeled with I-PRICE for 3-digit numbers and above and saved in CoNLL format at {output_path}.")
# Out:
# Data has been labeled with I-PRICE for 3-digit numbers and above and saved in CoNLL format at labeled_200_messages_with_price.conll.

# %%
Message_list = df['Message'].tolist()
Message_list
# Out:
# ["['Baby', 'Feeding', 'Bottle', 'Spoon', 'with', 'Container', 'Baby', 'Food', 'Feeder', 'High', 'Quality', 'የህፃናት', 'መመገቢያ', 'ጡጦ', 'Silicone', 'Squeeze', 'Spoon', 'Feeder', 'for', 'Infant', 'Food', 'Dispensing', 'and', 'Feeding', 'Safe', 'Material', 'Filterable', 'Food', 'Strong', 'Sealing', 'Easy', 'to', 'Use', 'ዋጋ', '400', 'ብር', 'ውስን', 'ፍሬ', 'ያለው', 'አድራሻ', 'ቁ', '1', 'መገናኛ', 'መሰረት', 'ደፋር', 'ሞል', 'ሁለተኛ', 'ፎቅ', 'ቢሮ', 'ቁ', 'S05', 'S06', 'ቁ', '2', 'ፒያሳ', 'ጊዮርጊስ', 'አደባባይ', 'ራመት_ታቦር_ኦዳ_ህንፃ', '1ኛ', 'ፎቅ', 'ሱቅ', 'ቁ', 'G', 'ፒያሳ', 'ቅርንጫፍ']",
#  "['ለመላው', 'የክርስትና', 'እምነት', 'ተከታዮች', 'በሙሉ', 'እንኳን', 'ለብርሃነ', 'መስቀሉ', 'በሰላም', 'አደረሳችሁ', 'አደረሰን', 'በዓሉ', 'የሰላም', 'የጤና', 'የፍቅር', 'የደስታ', 'የመተሳሰብ', 'በዓል', 'ይሁንልን', 'መልካም', 'የመስቀል', 'በዓል']",
# ...
